# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

a = pd.read_csv('sales所在周次节假日_剔除换货.csv')
#合并大类
a['大类'] = a['季节'] + a ['大类']
a = a.drop(columns = ['季节'])
a.head()

#map店铺名称
name = a['店铺名称']
le = preprocessing.LabelEncoder()
le.fit(name)
list(name)
le.transform(name)
tmp = le.transform(name)
a['店铺名称'] = tmp

#map合并大类
category = a['大类']
le.fit(category)
list(category)
le.transform(category)
tmp = le.transform(category)
a['大类'] = tmp

#周次序数特征
d = [0] * 10044
for i in range(10044):
    d[i]=53
tmp = a.loc[lambda a : a ['年份'] == 2016]
tmp['周次(年份)'] = tmp['周次'] + d
tmp1 = a.loc[lambda a : a['年份'] ==2015]
tmp1['周次(年份)'] = tmp1['周次']
a = pd.concat([tmp1,tmp])

#销量log
a['销量(剔除换货）'] = np.log1p(a['销量(剔除换货）'].values)
a
# Out:
# /home/lin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/lin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        店铺名称  地理位置指数    年份  周次  是否包含法定节假日  大类  销量(剔除换货）    均价（剔除换货）  促销（剔除换货）  \
# 0         0       7  2015   1          1   0  0.693147  499.666700  0.333333
# 1         0       7  2015   1          1   1  3.433987  513.066663  0.371160
# 2         0       7  2015   1          1   4  1.098612  683.833300  0.325790
# 3         0       7  2015   1          1   5  1.098612  799.600000  0.400000
# 4         0       7  2015   1          1  12  0.693147  375.600000  0.400000
# 5         0       7  2015   1          1  17  1.098612  366.333350  0.333333
# 6         0       7  2015   2          0   0  0.693147  799.000000  0.470277
# 7         0       7  2015   2          0   1  1.945910  645.833333  0.467205
# 8         0       7  2015   2          0  12  0.693147  563.000000  0.599574
# 9         0       7  2015   2          0  16  1.098612  354.000000  0.385201
# 10        0       7  2015   2          0  17  1.386294  392.333333  0.346482
# 11        0       7  2015   3          0   0  0.693147  499.000000  0.312070
# 12        0       7  2015   3          0   1  2.197225  557.000000  0.394616
# 13        0       7  2015   3          0   5  1.098612  800.000000  0.400200
# 14        0       7  2015   3          0  12  1.386294  507.000000  0.534247
# 15        0       7  2015   3          0  16  0.693147  239.000000  0.265851
# 16        0       7  2015   3          0  17  0.693147  399.000000  0.399399
# 17        0       7  2015   4          0   1  2.995732  566.526316  0.401927
# 18        0       7  2015   4          0   5  0.693147  899.000000  0.449725
# 19        0       7  2015   4          0  12  1.609438  473.500000  0.500264
# 20        0       7  2015   4          0  16  1.098612  360.000000  0.400445
# 21        0       7  2015   4          0  17  1.386294  423.000000  0.438039
# 22        0       7  2015   5          0   1  2.833213  568.187500  0.404332
# 23        0       7  2015   5          0   5  0.693147  899.000000  0.449725
# 24        0       7  2015   5          0  12  1.386294  468.000000  0.500178
# 25        0       7  2015   5          0  16  1.098612  334.000000  0.371524
# 26        0       7  2015   5          0  17  1.609438  374.750000  0.375125
# 27        0       7  2015   6          0   0  0.693147  639.000000  0.376104
# 28        0       7  2015   6          0   1  3.433987  574.902857  0.394941
# 29        0       7  2015   6          0  12  0.693147  375.600000  0.400000
# ...     ...     ...   ...  ..        ...  ..       ...         ...       ...
# 18133    29       7  2016  49          0   5  1.945910  521.818150  0.263234
# 18134    29       7  2016  49          0  12  3.806662  319.353459  0.340842
# 18135    29       7  2016  49          0  13  1.791759  312.429100  0.322424
# 18136    29       7  2016  49          0  16  2.564949  335.689408  0.349434
# 18137    29       7  2016  49          0  17  3.610918  351.117344  0.305585
# 18138    29       7  2016  50          0   0  0.693147  423.939400  0.303030
# 18139    29       7  2016  50          0   1  2.079442  454.242429  0.303030
# 18140    29       7  2016  50          0   3  1.945910  388.585883  0.303030
# 18141    29       7  2016  50          0  12  2.564949  313.957092  0.335245
# 18142    29       7  2016  50          0  16  1.386294  299.697000  0.303030
# 18143    29       7  2016  50          0  17  1.386294  333.030300  0.303030
# 18144    29       7  2016  51          0   1  1.791759  367.240000  0.238622
# 18145    29       7  2016  51          0   3  1.098612  499.600000  0.400000
# 18146    29       7  2016  51          0  12  1.791759  374.440000  0.402191
# 18147    29       7  2016  51          0  16  1.386294  452.666667  0.478675
# 18148    29       7  2016  51          0  17  0.693147  439.600000  0.400000
# 18149    29       7  2016  52          0   0  0.693147  533.000000  0.333333
# 18150    29       7  2016  52          0   1  2.564949  448.611108  0.294364
# 18151    29       7  2016  52          0   3  1.609438  414.500000  0.319092
# 18152    29       7  2016  52          0   4  0.693147  699.000000  0.279712
# 18153    29       7  2016  52          0  12  2.302585  311.370367  0.333969
# 18154    29       7  2016  52          0  16  0.693147  323.000000  0.333333
# 18155    29       7  2016  52          0  17  2.564949  379.555550  0.318776
# 18156    29       7  2016  53          0   0  1.609438  354.000000  0.199549
# 18157    29       7  2016  53          0   1  3.178054  409.695656  0.269406
# 18158    29       7  2016  53          0   2  0.693147  339.000000  0.260970
# 18159    29       7  2016  53          0   4  1.098612  584.000000  0.233693
# 18160    29       7  2016  53          0  12  1.098612  318.000000  0.333333
# 18161    29       7  2016  53          0  16  1.609438  269.500000  0.285487
# 18162    29       7  2016  53          0  17  2.302585  377.370367  0.317682
#
#        周次(年份)
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# 5           1
# 6           2
# 7           2
# 8           2
# 9           2
# 10          2
# 11          3
# 12          3
# 13          3
# 14          3
# 15          3
# 16          3
# 17          4
# 18          4
# 19          4
# 20          4
# 21          4
# 22          5
# 23          5
# 24          5
# 25          5
# 26          5
# 27          6
# 28          6
# 29          6
# ...       ...
# 18133     102
# 18134     102
# 18135     102
# 18136     102
# 18137     102
# 18138     103
# 18139     103
# 18140     103
# 18141     103
# 18142     103
# 18143     103
# 18144     104
# 18145     104
# 18146     104
# 18147     104
# 18148     104
# 18149     105
# 18150     105
# 18151     105
# 18152     105
# 18153     105
# 18154     105
# 18155     105
# 18156     106
# 18157     106
# 18158     106
# 18159     106
# 18160     106
# 18161     106
# 18162     106
#
# [18163 rows x 10 columns]

# %%
#方法定义
df = a
def one_hot_encoder(df, ohe_cols=['店铺名称','大类','周次','周次(年份)','年份']):
    '''
    One-Hot Encoder function
    '''
    print('Creating OHE features..\nOld df shape:{}'.format(df.shape))
    df = pd.get_dummies(df, columns=ohe_cols)
    print('New df shape:{}'.format(df.shape))
    return df

def create_sales_agg_monthwise_features(df, gpby_cols, target_col, agg_funcs):
    '''
    Creates various sales agg features with given agg functions  
    '''
    gpby = df.groupby(gpby_cols)
    newdf = df[gpby_cols].drop_duplicates().reset_index(drop=True)
    for agg_name, agg_func in agg_funcs.items():
        aggdf = gpby[target_col].agg(agg_func).reset_index()
        aggdf.rename(columns={target_col:target_col+'_'+agg_name}, inplace=True)
        newdf = newdf.merge(aggdf, on=gpby_cols, how='left')
    return newdf

# Creating sales lag features
def create_sales_lag_feats(df, gpby_cols, target_col, lags):
    gpby = df.groupby(gpby_cols)
    for i in lags:
        df['_'.join([target_col, 'lag', str(i)])] = \
                gpby[target_col].shift(i).values + np.random.normal(scale=1.6, size=(len(df),))
    return df

# Creating sales rolling mean features
def create_sales_rmean_feats(df, gpby_cols, target_col, windows, min_periods=2, 
                             shift=1, win_type=None):
    gpby = df.groupby(gpby_cols)
    for w in windows:
        df['_'.join([target_col, 'rmean', str(w)])] = \
            gpby[target_col].shift(shift).rolling(window=w, 
                                                  min_periods=min_periods,
                                                  win_type=win_type).mean().values +\
            np.random.normal(scale=1.6, size=(len(df),))
    return df

# Creating sales rolling median features
'''def create_sales_rmed_feats(df, gpby_cols, target_col, windows, min_periods=2, 
                            shift=1, win_type=None):
    gpby = df.groupby(gpby_cols)
    for w in windows:
        df['_'.join([target_col, 'rmed', str(w)])] = \
            gpby[target_col].shift(shift).rolling(window=w, 
                                                  min_periods=min_periods,
                                                  win_type=win_type).median().values +\
            np.random.normal(scale=1.6, size=(len(df),))
    return df
'''

# Creating sales exponentially weighted mean features
def create_sales_ewm_feats(df, gpby_cols, target_col, alpha=[0.9], shift=[1]):
    gpby = df.groupby(gpby_cols)
    for a in alpha:
        for s in shift:
            df['_'.join([target_col, 'lag', str(s), 'ewm', str(a)])] = \
                gpby[target_col].shift(s).ewm(alpha=a).mean().values
    return df

# %%
#设置训练数据，验证数据
masked_series = (df['年份']==2016) & (df['周次'].isin([1,2,3]))
masked_series2 = (df['年份']==2016) & (~(df['周次'].isin([1,2,3])))
df.loc[(masked_series), 'train_or_test'] = 'val'
df.loc[(masked_series2), 'train_or_test'] = 'no_train'
print('Train shape: {}'.format(df.loc[df['年份']==2015,:].shape))
print('Validation shape: {}'.format(df.loc[df.train_or_test=='val',:].shape))
#print('No train shape: {}'.format(df.loc[df.train_or_test=='no_train',:].shape))
#print('Test shape: {}'.format(df.loc[df['年份']==2016,:].shape))
# Out:
# Train shape: (8119, 11)
# Validation shape: (510, 11)

# %%
df
# Converting sales of validation period to nan so as to resemble test period
train = df
Y_val = train.loc[train.train_or_test=='val', '销量(剔除换货）'].values.reshape((-1))
Y_train = train.loc[train.train_or_test=='train', '销量(剔除换货）'].values.reshape((-1))
train.loc[train.train_or_test=='val', '销量(剔除换货）'] = np.nan
train
# Out:
#        店铺名称  地理位置指数    年份  周次  是否包含法定节假日  大类  销量(剔除换货）    均价（剔除换货）  促销（剔除换货）  \
# 0         0       7  2015   1          1   0  0.693147  499.666700  0.333333
# 1         0       7  2015   1          1   1  3.433987  513.066663  0.371160
# 18152    29       7  2016  52          0   4  0.693147  699.000000  0.279712
# 18153    29       7  2016  52          0  12  2.302585  311.370367  0.333969
# 18154    29       7  2016  52          0  16  0.693147  323.000000  0.333333
# 18155    29       7  2016  52          0  17  2.564949  379.555550  0.318776
# 18156    29       7  2016  53          0   0  1.609438  354.000000  0.199549
# 18157    29       7  2016  53          0   1  3.178054  409.695656  0.269406
# 18158    29       7  2016  53          0   2  0.693147  339.000000  0.260970
# 18159    29       7  2016  53          0   4  1.098612  584.000000  0.233693
# 18160    29       7  2016  53          0  12  1.098612  318.000000  0.333333
# 18161    29       7  2016  53          0  16  1.609438  269.500000  0.285487
# 18162    29       7  2016  53          0  17  2.302585  377.370367  0.317682
#
#        周次(年份)           ...            销量(剔除换货）_lag_3_ewm_0.5  \
# 0           1           ...                               NaN
# 1           1           ...                               NaN
# 2           1           ...                               NaN
# 3           1           ...                               NaN
# 4           1           ...                               NaN
# 5           1           ...                               NaN
# 6           2           ...                               NaN
# 7           2           ...                               NaN
# 8           2           ...                               NaN
# 9           2           ...                               NaN
# 10          2           ...                               NaN
# 11          3           ...                               NaN
# 12          3           ...                               NaN
# 13          3           ...                               NaN
# 14          3           ...                               NaN
# 15          3           ...                               NaN
# 16          3           ...                               NaN
# 17          4           ...                          3.433987
# 18          4           ...                          3.433987
# 19          4           ...                          1.241315
# 20          4           ...                          1.241315
# 21          4           ...                          1.132589
# 22          5           ...                          1.623651
# 23          5           ...                          1.336450
# 24          5           ...                          1.000357
# 25          5           ...                          1.050563
# 26          5           ...                          1.220252
# 27          6           ...                          0.955276
# 28          6           ...                          1.577923
# 29          6           ...                          1.481980
# ...       ...           ...                               ...
# 18133     102           ...                          2.117511
# 18134     102           ...                          2.759354
# 18135     102           ...                          2.184396
# 18136     102           ...                          2.411727
# 18137     102           ...                          2.678083
# 18138     103           ...                          2.032189
# 18139     103           ...                          2.872880
# 18140     103           ...                          1.783014
# 18141     103           ...                          2.336693
# 18142     103           ...                          2.064226
# 18143     103           ...                          2.005068
# 18144     104           ...                          2.500400
# 18145     104           ...                          2.223155
# 18146     104           ...                          2.007457
# 18147     104           ...                          1.350302
# 18148     104           ...                          1.648106
# 18149     105           ...                          1.170627
# 18150     105           ...                          2.800722
# 18151     105           ...                          3.148615
# 18152     105           ...                          2.267455
# 18153     105           ...                          3.037058
# 18154     105           ...                          2.801004
# 18155     105           ...                          3.205961
# 18156     106           ...                          2.701593
# 18157     106           ...                          2.390517
# 18158     106           ...                          2.390517
# 18159     106           ...                          1.529247
# 18160     106           ...                          2.121077
# 18161     106           ...                          1.729193
# 18162     106           ...                          1.552213
#
#        销量(剔除换货）_lag_4_ewm_0.5  销量(剔除换货）_lag_5_ewm_0.5  销量(剔除换货）_lag_6_ewm_0.5  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# 5                         NaN                     NaN                     NaN
# 20                        NaN                     NaN                     NaN
# 21                        NaN                     NaN                     NaN
# 22                        NaN                     NaN                     NaN
# 23                        NaN                     NaN                     NaN
# 24                        NaN                     NaN                     NaN
# 25                        NaN                     NaN                     NaN
# 26                        NaN                     NaN                     NaN
# 27                        NaN                     NaN                     NaN
# 28                        NaN                     NaN                     NaN
# 29                        NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 18133                1.737399                1.499227                1.890920
# 18134                1.841655                1.789583                2.257421
# 18135                2.274853                1.699472                1.255718
# 18136                2.033306                1.542850                1.843579
# 18137                1.821372                1.320707                2.503472
# 18138                1.603833                1.209654                2.043862
# 18139                1.148490                0.951394                1.359124
# 18140                0.920819                1.168847                1.023839
# 18141                1.611702                1.557381                1.553454
# 18142                1.152425                1.674571                1.469731
# 18143                1.269359                1.642004                1.284013
# 18144                1.327827                1.167575                0.988453
# 18145                1.010487                0.930361                1.187416
# 18146                1.478199                1.616473                1.566704
# 18147                1.634979                1.154810                1.679238
# 18148                1.510637                1.270552                1.644337
# 18149                1.101892                1.328423                1.371471
# 18150                1.749894                1.357359                1.032307
# 18151                1.424253                1.025253                0.862726
# 18152                1.261433                1.205774                1.124511
# 18153                1.829664                1.575842                1.713548
# 18154                2.157285                1.683801                1.203348
# 18155                1.974522                1.535048                1.294821
# 18156                1.333835                1.114097                1.340558
# 18157                2.864142                1.755996                1.363426
# 18158                2.864142                1.755996                1.363426
# 18159                1.416812                1.317740                1.378672
# 18160                2.550747                1.934972                1.702808
# 18161                2.597846                2.228270                1.750249
# 18162                2.776733                2.002974                1.562401
#
#        销量(剔除换货）_lag_18_ewm_0.5  销量(剔除换货）_lag_36_ewm_0.5  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                         NaN                      NaN
# 14                         NaN                      NaN
# 15                         NaN                      NaN
# 16                         NaN                      NaN
# 17                         NaN                      NaN
# 18                         NaN                      NaN
# 19                         NaN                      NaN
# 20                         NaN                      NaN
# 21                         NaN                      NaN
# 22                         NaN                      NaN
# 23                         NaN                      NaN
# 24                         NaN                      NaN
# 25                         NaN                      NaN
# 26                         NaN                      NaN
# 27                         NaN                      NaN
# 28                         NaN                      NaN
# 29                         NaN                      NaN
# ...                        ...                      ...
# 18133                 1.425263                 1.911665
# 18134                 2.072705                 1.633901
# 18135                 1.360630                 1.633901
# 18136                 1.579623                 1.213082
# 18137                 1.337220                 3.134604
# 18138                 1.361854                 3.134604
# 18139                 1.361854                 1.893790
# 18140                 1.361854                 1.893790
# 18141                 1.381422                 2.843513
# 18142                 1.728904                 1.974116
# 18143                 1.539852                 2.204674
# 18144                 1.539852                 1.894498
# 18145                 1.539852                 1.894498
# 18146                 2.310362                 1.825069
# 18147                 1.307914                 1.805924
# 18148                 1.351299                 2.122497
# 18149                 1.369685                 2.122497
# 18150                 1.369685                 3.314130
# 18151                 1.369685                 3.314130
# 18152                 1.563360                 3.314130
# 18153                 1.799654                 2.681074
# 18154                 1.412227                 2.681074
# 18155                 1.034705                 1.854104
# 18156                 1.891789                 1.854104
# 18157                 2.849392                 1.283476
# 18158                 2.849392                 1.283476
# 18159                 1.406167                 1.283476
# 18160                 2.487818                 2.382985
# 18161                 1.746320                 2.382985
# 18162                 1.411891                 1.783974
#
#        销量(剔除换货）_lag_53_ewm_0.5
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ...                        ...
# 18133                 1.519051
# 18134                 3.963172
# 18135                 2.407211
# 18136                 2.497021
# 18137                 1.752466
# 18138                 1.752466
# 18139                 1.752466
# 18140                 1.752466
# 18141                 1.624464
# 18142                 1.026965
# 18143                 1.228910
# 18144                 1.228910
# 18145                 1.228910
# 18146                 1.689349
# 18147                 1.322707
# 18148                 2.302066
# 18149                 2.302066
# 18150                 2.302066
# 18151                 2.302066
# 18152                 2.302066
# 18153                 2.091332
# 18154                 1.176417
# 18155                 1.132313
# 18156                 1.132313
# 18157                 1.132313
# 18158                 1.132313
# 18159                 1.132313
# 18160                 1.100373
# 18161                 1.433626
# 18162                 1.406791
#
# [18163 rows x 83 columns]

# %%
# # Creating sales lag, rolling mean, rolling median, ohe features of the above train set
train = create_sales_lag_feats(train, gpby_cols=['店铺名称','大类'], target_col='销量(剔除换货）', 
                               lags=[3,4,5,6,7,8,9,18,36,53])

train = create_sales_rmean_feats(train, gpby_cols=['店铺名称','大类'], 
                                 target_col='销量(剔除换货）', windows=[18,36], 
                                 min_periods=10, win_type='triang') #98,119,91,182,

train = create_sales_ewm_feats(train, gpby_cols=['店铺名称','大类'], 
                               target_col='销量(剔除换货）', 
                               alpha=[0.95, 0.9, 0.8, 0.7, 0.6, 0.5], 
                               shift=[3,4,5,6,7,8,9,18,36,53])

train = one_hot_encoder(train, ohe_cols=['店铺名称','大类','周次','周次(年份)','年份']) 

val = train.loc[train.train_or_test=='val', :]
train = train.loc[train.train_or_test=='no_train', :]
print('Train shape:{}, Val shape:{}'.format(train.shape, val.shape))
# Out:
# Creating OHE features..
# Old df shape:(18163, 83)
# New df shape:(18163, 288)
# Train shape:(9534, 288), Val shape:(510, 288)

# %%
avoid_cols = ['周次(年份)','sales', '销量', 'train_or_test',  '年份']
cols = [col for col in train.columns if col not in avoid_cols]
#print('No of training features: {} \nAnd they are:{}'.format(len(cols), cols))
#设置对称的绝对百分比误差
def smape(preds, target):
    '''
    Function to calculate SMAPE
    '''
    n = len(preds)
    masked_arr = ~((preds==0)&(target==0))
    preds, target = preds[masked_arr], target[masked_arr]
    num = np.abs(preds-target)
    denom = np.abs(preds)+np.abs(target)
    smape_val = (200*np.sum(num/denom))/n
    return smape_val

def lgbm_smape(preds, train_data):
    '''
    Custom Evaluation Function for LGBM
    '''
    labels = train_data.get_label()
    smape_val = smape(np.expm1(preds), np.expm1(labels))
    return 'SMAPE', smape_val, False

# LightGBM 参数
lgb_params = {'task':'train', 'boosting_type':'gbdt', 'objective':'regression', 
              'metric': {'mae'}, 'num_leaves': 10, 'learning_rate': 0.02, 
              'feature_fraction': 0.8, 'max_depth': 5, 'verbose': 0, 
              'num_boost_round':15000, 'early_stopping_rounds':200, 'nthread':-1}

import lightgbm as lgb
import time
lgbtrain = lgb.Dataset(data=train.loc[:,cols].values, label=Y_train, 
                       feature_name=cols)
lgbval = lgb.Dataset(data=val.loc[:,cols].values, label=Y_val, 
                     reference=lgbtrain, feature_name=cols)
def lgb_validation(params, lgbtrain, lgbval, X_val, Y_val, verbose_eval):
    t0 = time.time()
    evals_result = {}
    model = lgb.train(params, lgbtrain, num_boost_round=params['num_boost_round'], 
                      valid_sets=[lgbtrain, lgbval], feval=lgbm_smape, 
                      early_stopping_rounds=params['early_stopping_rounds'], 
                      evals_result=evals_result, verbose_eval=verbose_eval)
    print(model.best_iteration)
    print('Total time taken to build the model: ', (time.time()-t0)/60, 'minutes!!')
    pred_Y_val = model.predict(X_val, num_iteration=model.best_iteration)
    pred_Y_val = np.expm1(pred_Y_val)
    Y_val = np.expm1(Y_val)
    val_df = pd.DataFrame(columns=['true_Y_val','pred_Y_val'])
    val_df['pred_Y_val'] = pred_Y_val
    val_df['true_Y_val'] = Y_val
    print(val_df.shape)
    print(val_df.sample(5))
    print('SMAPE for validation data is:{}'.format(smape(pred_Y_val, Y_val)))
    return model, val_df
model, val_df = lgb_validation(lgb_params, lgbtrain, lgbval, val.loc[:,cols].values, 
                               Y_val, verbose_eval=500)
# Out:
# /home/lin/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/lin/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:123: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-42-30e0c39c1290> in <module>
#      55     return model, val_df
#      56 model, val_df = lgb_validation(lgb_params, lgbtrain, lgbval, val.loc[:,cols].values,
# ---> 57                                Y_val, verbose_eval=500)
#
# <ipython-input-42-30e0c39c1290> in lgb_validation(params, lgbtrain, lgbval, X_val, Y_val, verbose_eval)
#      41                       valid_sets=[lgbtrain, lgbval], feval=lgbm_smape,
#      42                       early_stopping_rounds=params['early_stopping_rounds'],
# ---> 43                       evals_result=evals_result, verbose_eval=verbose_eval)
#      44     print(model.best_iteration)
#      45     print('Total time taken to build the model: ', (time.time()-t0)/60, 'minutes!!')
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     195     # construct booster
#     196     try:
# --> 197         booster = Booster(params=params, train_set=train_set)
#     198         if is_valid_contain_train:
#     199             booster.set_train_data_name(train_data_name)
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, silent)
#    1550             self.handle = ctypes.c_void_p()
#    1551             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1552                 train_set.construct().handle,
#    1553                 c_str(params_str),
#    1554                 ctypes.byref(self.handle)))
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in construct(self)
#     999                                 init_score=self.init_score, predictor=self._predictor,
#    1000                                 silent=self.silent, feature_name=self.feature_name,
# -> 1001                                 categorical_feature=self.categorical_feature, params=self.params)
#    1002             if self.free_raw_data:
#    1003                 self.data = None
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#     801                 raise TypeError('Cannot initialize Dataset from {}'.format(type(data).__name__))
#     802         if label is not None:
# --> 803             self.set_label(label)
#     804         if self.get_label() is None:
#     805             raise ValueError("Label should not be None")
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in set_label(self, label)
#    1297         if self.handle is not None:
#    1298             label = list_to_1d_numpy(_label_from_pandas(label), name='label')
# -> 1299             self.set_field('label', label)
#    1300         return self
#    1301
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in set_field(self, field_name, data)
#    1143             ptr_data,
#    1144             ctypes.c_int(len(data)),
# -> 1145             ctypes.c_int(type_data)))
#    1146         return self
#    1147
#
# ~/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py in _safe_call(ret)
#      44     """
#      45     if ret != 0:
# ---> 46         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      47
#      48
#
# LightGBMError: Length of label is not same with #data
