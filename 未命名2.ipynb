# %%
import pandas as pd

all_data01 = pd.read_csv ('sales所在周次节假日.csv')
all_data01.describe()
all_data02 = pd.read_csv ('sales所在周次节假日_剔除换货.csv')
all_data02.describe()
all_data03 = pd.read_csv ('sales所在周次节假日_剔除换货负销量.csv')
all_data03.describe()
# Out:
#              地理位置指数            年份            周次     是否包含法定节假日    销量（剔除换货负销量  \
# count  18465.000000  18465.000000  18465.000000  18465.000000  18465.000000
# mean       5.503331   2015.552613     27.617872      0.184565      8.018792
# std        2.596221      0.497238     15.184470      0.387955     16.505810
# min        1.000000   2015.000000      1.000000      0.000000      1.000000
# 25%        7.000000   2015.000000     14.000000      0.000000      2.000000
# 50%        7.000000   2016.000000     28.000000      0.000000      4.000000
# 75%        7.000000   2016.000000     40.000000      0.000000      9.000000
# max        7.000000   2016.000000     53.000000      1.000000    912.000000
#
#         均价（剔除换货负销量）   促销（剔除换货负销量）
# count  18465.000000  18465.000000
# mean     403.695878      0.366986
# std      150.004270      0.094107
# min       30.000000      0.032120
# 25%      309.166667      0.307159
# 50%      384.000000      0.370047
# 75%      463.333333      0.424161
# ...

# %%
all_data01 = pd.read_csv ('sales所在周次节假日.csv')
all_data01.describe()
# Out:
#              地理位置指数            周次     是否包含法定节假日            销量            促销
# count  18170.000000  18170.000000  18170.000000  18170.000000  18170.000000
# mean       5.500826     27.653385      0.185581      7.885911      0.364673
# std        2.597671     15.186189      0.388779     16.437344      0.092767
# min        1.000000      1.000000      0.000000      1.000000     -0.558496
# 25%        7.000000     14.000000      0.000000      2.000000      0.305429
# 50%        7.000000     28.000000      0.000000      4.000000      0.368357
# 75%        7.000000     40.000000      0.000000      9.000000      0.421410
# max        7.000000     53.000000      1.000000    912.000000      1.222469

# %%
all_data02 = pd.read_csv ('sales所在周次节假日_剔除换货.csv')
all_data02.describe()
# Out:
#              地理位置指数            年份            周次     是否包含法定节假日      销量(剔除换货）  \
# count  18163.000000  18163.000000  18163.000000  18163.000000  18163.000000
# mean       5.501569   2015.552992     27.652701      0.185432      7.880031
# std        2.597241      0.497198     15.181708      0.388658     16.436671
# min        1.000000   2015.000000      1.000000      0.000000      1.000000
# 25%        7.000000   2015.000000     14.000000      0.000000      2.000000
# 50%        7.000000   2016.000000     28.000000      0.000000      4.000000
# 75%        7.000000   2016.000000     40.000000      0.000000      9.000000
# max        7.000000   2016.000000     53.000000      1.000000    912.000000
#
#            均价（剔除换货）      促销（剔除换货）
# count  18163.000000  18163.000000
# mean     399.822747      0.364135
# std      142.264912      0.089089
# min       30.000000      0.032120
# 25%      307.981075      0.305955
# 50%      382.500000      0.368088
# 75%      459.225000      0.420665
# ...
