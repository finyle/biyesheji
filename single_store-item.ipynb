# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

all_data = pd.read_csv('sales所在周次节假日_剔除换货.csv')
all_data.rename(columns={'店铺名称':'store','地理位置指数':'position','年份':'years','周次':'weeks','是否包含法定节假日':'Isholiday','季节':'season','大类':'item','销量(剔除换货）':'sales','均价（剔除换货）':'prices','促销（剔除换货）':'discount'},inplace=True)
all_data.shape
# Out:
# (18163, 10)

# %%
a = all_data
a['item'].drop_duplicates().shape
# Out:
# (12,)

# %%
a_mix = a['a_item'] = a['season'] + a['item']
a_mix.drop_duplicates().shape
# Out:
# (19,)

# %%
a.groupby(['store']).max()
# Out:
#             position  years  weeks  Isholiday season item  sales       prices  \
# store
# 深圳前进天虹             7   2016     53          1     秋季   鱼嘴     91   950.000000
# 深圳华南城JB            7   2016     53          1     秋季   鱼嘴     44   674.000000
# 深圳华强北茂业            1   2016     53          1     秋季   鱼嘴    138  1250.000000
# 深圳南山崇尚百货           7   2016     53          1     秋季   鱼嘴     29   835.000000
# 深圳南山常兴天虹           7   2016     53          1     秋季   鱼嘴    331  1057.571433
# 深圳南山海雅百货           1   2016     53          1     秋季   鱼嘴    908  1099.000000
# 深圳后海天虹             1   2016     53          1     秋季   鱼嘴     71   999.000000
# 深圳坂田天虹             7   2016     53          1     秋季   鱼嘴     73   800.000000
# 深圳宝安公明天虹           7   2016     53          1     秋季   鱼嘴    177  1099.000000
# 深圳宝安创业天虹           7   2016     53          1     秋季   鱼嘴    912   943.000000
# 深圳布吉天虹             7   2016     53          1     秋季   鱼嘴    113  1187.000000
# ...

# %%
week_5 = a.loc[lambda a : a['years'] == 2015]
week_6 = a.loc[lambda a : a['years'] == 2016]
week_6['weeks'] += 53
a = pd.concat([week_5,week_6])
a
# Out:
# /home/lin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           store  position  years  weeks  Isholiday season item  sales  \
# 0        深圳前进天虹         7   2015      1          1     冬季   中靴      1
# 1        深圳前进天虹         7   2015      1          1     冬季   低靴     30
# 2        深圳前进天虹         7   2015      1          1     冬季   长靴      2
# 3        深圳前进天虹         7   2015      1          1     冬季   高靴      2
# 4        深圳前进天虹         7   2015      1          1     春季   浅口      1
# 5        深圳前进天虹         7   2015      1          1     秋季   深口      2
# ...

# %%
store_name = a['store'].drop_duplicates()
store_name.shape
# Out:
# (30,)

# %%
df = pd.DataFrame(a.groupby(['weeks','item']).sum()['sales']).unstack()
df.plot(figsize=(16,9),title = 'Weekly Item Sales')
plt.show()

# %%
item_

# %%
df = pd.DataFrame(a.groupby(['weeks','store']).sum()['sales']).unstack()
df.plot(figsize=(16,9),title='Weekly Store Sales')
#stores.sort_index(inplace = True)
#stores.plot(figsize=(16,9), title='Weekly Store Sales', legend=None)
plt.show()

# %%
e_haiya = a.loc[lambda a : a['store'] == '深圳南山海雅百货']

# %%
e_haiya
# Out:
#          store  position  years  weeks  Isholiday season item  sales  \
# 2912  深圳南山海雅百货         1   2015      1          1     冬季   中靴      5
# 2913  深圳南山海雅百货         1   2015      1          1     冬季   低靴     33
# 2914  深圳南山海雅百货         1   2015      1          1     春季   浅口      2
# 2915  深圳南山海雅百货         1   2015      1          1     秋季   浅口      5
# 2916  深圳南山海雅百货         1   2015      1          1     秋季   深口      2
# 2917  深圳南山海雅百货         1   2015      2          0     冬季   中靴      1
# 2918  深圳南山海雅百货         1   2015      2          0     冬季   低靴     12
# 2919  深圳南山海雅百货         1   2015      2          0     春季   浅口      1
# 2920  深圳南山海雅百货         1   2015      3          0     冬季   低靴      7
# 2921  深圳南山海雅百货         1   2015      3          0     春季   浅口      2
# 2922  深圳南山海雅百货         1   2015      3          0     秋季   浅口      1
# 2923  深圳南山海雅百货         1   2015      4          0     冬季   低靴     10
# 2924  深圳南山海雅百货         1   2015      4          0     春季   浅口      1
# ...

# %%
pd.date_range(start='1/1/2015',end='31/12/2016',freq='W')
# Out:
# DatetimeIndex(['2015-01-04', '2015-01-11', '2015-01-18', '2015-01-25',
#                '2015-02-01', '2015-02-08', '2015-02-15', '2015-02-22',
#                '2015-03-01', '2015-03-08',
#                ...
#                '2016-10-23', '2016-10-30', '2016-11-06', '2016-11-13',
#                '2016-11-20', '2016-11-27', '2016-12-04', '2016-12-11',
#                '2016-12-18', '2016-12-25'],
#               dtype='datetime64[ns]', length=104, freq='W-SUN')

# %%
week_6 = e_haiya.loc[lambda a: a['years'] == 2016]
week_6['weeks'] += 53
week_6
# Out:
# /home/lin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          store  position  years  weeks  Isholiday season item  sales  \
# 3190  深圳南山海雅百货         1   2016     54          1     冬季   中靴      9
# 3191  深圳南山海雅百货         1   2016     54          1     冬季   低靴     79
# 3192  深圳南山海雅百货         1   2016     54          1     冬季   长靴     11
# 3193  深圳南山海雅百货         1   2016     54          1     冬季   高靴      9
# 3194  深圳南山海雅百货         1   2016     54          1     春季   浅口      9
# 3195  深圳南山海雅百货         1   2016     54          1     春季   深口      1
# 3196  深圳南山海雅百货         1   2016     54          1     秋季   浅口     24
# 3197  深圳南山海雅百货         1   2016     54          1     秋季   深口     64
# ...

# %%
week_5 = e_haiya.loc[lambda a: a['years'] == 2015]
e_haiya = pd.concat([week_5,week_6])
e_haiya
# Out:
#          store  position  years  weeks  Isholiday season item  sales  \
# 2912  深圳南山海雅百货         1   2015      1          1     冬季   中靴      5
# 2913  深圳南山海雅百货         1   2015      1          1     冬季   低靴     33
# 2914  深圳南山海雅百货         1   2015      1          1     春季   浅口      2
# 2915  深圳南山海雅百货         1   2015      1          1     秋季   浅口      5
# 2916  深圳南山海雅百货         1   2015      1          1     秋季   深口      2
# 2917  深圳南山海雅百货         1   2015      2          0     冬季   中靴      1
# 2918  深圳南山海雅百货         1   2015      2          0     冬季   低靴     12
# 2919  深圳南山海雅百货         1   2015      2          0     春季   浅口      1
# 2920  深圳南山海雅百货         1   2015      3          0     冬季   低靴      7
# 2921  深圳南山海雅百货         1   2015      3          0     春季   浅口      2
# 2922  深圳南山海雅百货         1   2015      3          0     秋季   浅口      1
# 2923  深圳南山海雅百货         1   2015      4          0     冬季   低靴     10
# 2924  深圳南山海雅百货         1   2015      4          0     春季   浅口      1
# ...

# %%
#df = pd.DataFrame(a.groupby(['weeks','store']).sum()['sales']).unstack()
df = pd.DataFrame(e_haiya.groupby(['weeks','item']).sum()['sales']).unstack()
df.sort_index(inplace = True)
df.plot(figsize=(16,9), title='Weekly Store Sales', legend=None)
plt.show()
