# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
from scipy import stats
from scipy.stats import norm,skew
all_data = pd.read_csv('sales所在周次节假日_剔除换货.csv')
all_data.head()
# Out:
#      店铺名称  地理位置指数    年份  周次  是否包含法定节假日  季节  大类  销量(剔除换货）    均价（剔除换货）  促销（剔除换货）
# 0  深圳前进天虹       7  2015   1          1  冬季  中靴         1  499.666700  0.333333
# 1  深圳前进天虹       7  2015   1          1  冬季  低靴        30  513.066663  0.371160
# 2  深圳前进天虹       7  2015   1          1  冬季  长靴         2  683.833300  0.325790
# 3  深圳前进天虹       7  2015   1          1  冬季  高靴         2  799.600000  0.400000
# 4  深圳前进天虹       7  2015   1          1  春季  浅口         1  375.600000  0.400000

# %%
name = all_data['店铺名称']
name.shape
# Out:
# (18163,)

# %%
#a1 = name['店铺名称']
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(name)
list(name)
le.transform(name)
# Out:
# array([ 0,  0,  0, ..., 29, 29, 29])

# %%
a = le.transform(name)
all_data['店铺名称'] = a
all_data.head()
# Out:
#    店铺名称  地理位置指数    年份  周次  是否包含法定节假日                  季节  大类  销量(剔除换货）  \
# 0     0       7  2015   1          1  冬季中靴中靴中靴中靴中靴中靴中靴中靴  中靴         1
# 1     0       7  2015   1          1  冬季低靴低靴低靴低靴低靴低靴低靴低靴  低靴        30
# 2     0       7  2015   1          1  冬季长靴长靴长靴长靴长靴长靴长靴长靴  长靴         2
# 3     0       7  2015   1          1  冬季高靴高靴高靴高靴高靴高靴高靴高靴  高靴         2
# 4     0       7  2015   1          1  春季浅口浅口浅口浅口浅口浅口浅口浅口  浅口         1
#
#      均价（剔除换货）  促销（剔除换货）
# 0  499.666700  0.333333
# 1  513.066663  0.371160
# 2  683.833300  0.325790
# 3  799.600000  0.400000
# 4  375.600000  0.400000

# %%
all_data.head()
# Out:
#    店铺名称  地理位置指数    年份  周次  是否包含法定节假日                  季节  大类  销量(剔除换货）  \
# 0     0       7  2015   1          1  冬季中靴中靴中靴中靴中靴中靴中靴中靴  中靴         1
# 1     0       7  2015   1          1  冬季低靴低靴低靴低靴低靴低靴低靴低靴  低靴        30
# 2     0       7  2015   1          1  冬季长靴长靴长靴长靴长靴长靴长靴长靴  长靴         2
# 3     0       7  2015   1          1  冬季高靴高靴高靴高靴高靴高靴高靴高靴  高靴         2
# 4     0       7  2015   1          1  春季浅口浅口浅口浅口浅口浅口浅口浅口  浅口         1
#
#      均价（剔除换货）  促销（剔除换货）
# 0  499.666700  0.333333
# 1  513.066663  0.371160
# 2  683.833300  0.325790
# 3  799.600000  0.400000
# 4  375.600000  0.400000

# %%
all_data.get('深圳前进天虹')

# %%
a1 = all_data.get('深圳前进天虹')
print (a1)
# Out:
# None

# %%
all_data.loc('深圳前进天虹':'深圳前进天虹')
# Out:
#   File "<ipython-input-11-3d454224f769>", line 1
#     all_data.loc('深圳前进天虹':'深圳前进天虹')
#                          ^
# SyntaxError: invalid syntax

# %%
df.loc[lambda df: df['shield'] == 8]
# Out:
# Empty DataFrame
# Columns: [店铺名称, 地理位置指数, 年份, 周次, 是否包含法定节假日, 季节, 大类, 销量, 均价, 促销]
# Index: []

# %%
all_data.loc[lambda all_data: all_data['店铺名称'] == '深圳前进天虹']
# Out:
#        店铺名称  地理位置指数     年份  周次  是否包含法定节假日  季节  大类  销量           均价        促销
# 0    深圳前进天虹       7  2,015   1          1  冬季  中靴   2          599  0.374818
# 1    深圳前进天虹       7  2,015   1          1  冬季  低靴  29       506.66  0.367592
# 2    深圳前进天虹       7  2,015   1          1  冬季  长靴   2       683.83  0.325790
# 3    深圳前进天虹       7  2,015   1          1  冬季  高靴   2          800  0.400000
# 4    深圳前进天虹       7  2,015   1          1  春季  浅口   1        375.6  0.400000
# 5    深圳前进天虹       7  2,015   1          1  秋季  深口   2          366  0.333333
# 6    深圳前进天虹       7  2,015   2          0  冬季  中靴   1          799  0.470277
# 7    深圳前进天虹       7  2,015   2          0  冬季  低靴   6  645.8333333  0.467205
# 8    深圳前进天虹       7  2,015   2          0  春季  浅口   1          563  0.599574
# 9    深圳前进天虹       7  2,015   2          0  秋季  浅口   2          354  0.385201
# 10   深圳前进天虹       7  2,015   2          0  秋季  深口   3  392.3333333  0.346482
# 11   深圳前进天虹       7  2,015   3          0  冬季  中靴   1          499  0.312070
# 12   深圳前进天虹       7  2,015   3          0  冬季  低靴   8          557  0.394616
# 13   深圳前进天虹       7  2,015   3          0  冬季  高靴   2          800  0.400200
# 14   深圳前进天虹       7  2,015   3          0  春季  浅口   3          507  0.534247
# 15   深圳前进天虹       7  2,015   3          0  秋季  浅口   1          239  0.265851
# 16   深圳前进天虹       7  2,015   3          0  秋季  深口   1          399  0.399399
# 17   深圳前进天虹       7  2,015   4          0  冬季  低靴  19  566.5263158  0.398947
# 18   深圳前进天虹       7  2,015   4          0  冬季  高靴   1          899  0.449725
# 19   深圳前进天虹       7  2,015   4          0  春季  浅口   4        473.5  0.500264
# 20   深圳前进天虹       7  2,015   4          0  秋季  浅口   2          360  0.400445
# 21   深圳前进天虹       7  2,015   4          0  秋季  深口   3          423  0.438039
# 22   深圳前进天虹       7  2,015   5          0  冬季  低靴  16     568.1875  0.404332
# 23   深圳前进天虹       7  2,015   5          0  冬季  高靴   1          899  0.449725
# 24   深圳前进天虹       7  2,015   5          0  春季  浅口   3          468  0.500178
# 25   深圳前进天虹       7  2,015   5          0  秋季  浅口   2          334  0.371524
# 26   深圳前进天虹       7  2,015   5          0  秋季  深口   4       374.75  0.375125
# 27   深圳前进天虹       7  2,015   6          0  冬季  中靴   1          639  0.376104
# 28   深圳前进天虹       7  2,015   6          0  冬季  低靴  30  574.9028567  0.394941
# 29   深圳前进天虹       7  2,015   6          0  春季  浅口   1        375.6  0.400000
# ..      ...     ...    ...  ..        ...  ..  ..  ..          ...       ...
# 649  深圳前进天虹       7  2,016  50          0  冬季  中靴   8  487.1666625  0.333333
# 650  深圳前进天虹       7  2,016  50          0  冬季  低靴  90  494.8666711  0.330621
# 651  深圳前进天虹       7  2,016  50          0  冬季  裸靴  14  442.5238143  0.333333
# 652  深圳前进天虹       7  2,016  50          0  冬季  长靴   5        719.4  0.315665
# 653  深圳前进天虹       7  2,016  50          0  冬季  高靴   8   591.166675  0.288515
# 654  深圳前进天虹       7  2,016  50          0  春季  中空   1          376  0.400426
# 655  深圳前进天虹       7  2,016  50          0  春季  后空   1          305  0.305305
# 656  深圳前进天虹       7  2,016  50          0  春季  浅口  32     366.9375  0.393921
# 657  深圳前进天虹       7  2,016  50          0  春季  深口   4       409.25  0.425637
# 658  深圳前进天虹       7  2,016  50          0  秋季  浅口  15        362.8  0.375440
# 659  深圳前进天虹       7  2,016  50          0  秋季  深口  22  419.6212136  0.372575
# 660  深圳前进天虹       7  2,016  51          0  冬季  中靴   3  555.6666667  0.362628
# 661  深圳前进天虹       7  2,016  51          0  冬季  低靴  12   559.472225  0.390602
# 662  深圳前进天虹       7  2,016  51          0  春季  浅口  11  417.1818182  0.444714
# 663  深圳前进天虹       7  2,016  51          0  春季  深口   1          376  0.400426
# 664  深圳前进天虹       7  2,016  51          0  秋季  浅口   3  375.6666667  0.387685
# 665  深圳前进天虹       7  2,016  51          0  秋季  深口   5          397  0.342537
# 666  深圳前进天虹       7  2,016  52          0  冬季  中靴   4   524.666675  0.333333
# 667  深圳前进天虹       7  2,016  52          0  冬季  低靴  45  523.8000022  0.355762
# 668  深圳前进天虹       7  2,016  52          0  冬季  裸靴   8  441.3333375  0.333333
# 669  深圳前进天虹       7  2,016  52          0  冬季  高靴   1          799  0.420748
# 670  深圳前进天虹       7  2,016  52          0  春季  浅口  10        396.1  0.412175
# 671  深圳前进天虹       7  2,016  52          0  秋季  浅口   8       379.38  0.396111
# 672  深圳前进天虹       7  2,016  52          0  秋季  深口   8       423.04  0.356546
# 673  深圳前进天虹       7  2,016  53          0  冬季  中靴   3          548  0.365355
# 674  深圳前进天虹       7  2,016  53          0  冬季  低靴  12        556.5  0.371248
# 675  深圳前进天虹       7  2,016  53          0  冬季  高靴   1          799  0.363347
# 676  深圳前进天虹       7  2,016  53          0  春季  浅口   8      393.125  0.418107
# 677  深圳前进天虹       7  2,016  53          0  秋季  浅口   1          388  0.400413
# 678  深圳前进天虹       7  2,016  53          0  秋季  深口   5        458.8  0.402809
#
# [679 rows x 10 columns]

# %%
a1 = all_data.loc[lambda all_data: all_data['店铺名称'] == '深圳前进天虹']
print a1
# Out:
#   File "<ipython-input-14-85bdd75a2fdd>", line 2
#     print a1
#            ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(a1)?

# %%
a1 = all_data.loc[lambda all_data: all_data['店铺名称'] == '深圳前进天虹']
print (a1)
# Out:
#        店铺名称  地理位置指数     年份  周次  是否包含法定节假日  季节  大类  销量           均价        促销
# 0    深圳前进天虹       7  2,015   1          1  冬季  中靴   2          599  0.374818
# 1    深圳前进天虹       7  2,015   1          1  冬季  低靴  29       506.66  0.367592
# 2    深圳前进天虹       7  2,015   1          1  冬季  长靴   2       683.83  0.325790
# 3    深圳前进天虹       7  2,015   1          1  冬季  高靴   2          800  0.400000
# 4    深圳前进天虹       7  2,015   1          1  春季  浅口   1        375.6  0.400000
# 5    深圳前进天虹       7  2,015   1          1  秋季  深口   2          366  0.333333
# 6    深圳前进天虹       7  2,015   2          0  冬季  中靴   1          799  0.470277
# 7    深圳前进天虹       7  2,015   2          0  冬季  低靴   6  645.8333333  0.467205
# 8    深圳前进天虹       7  2,015   2          0  春季  浅口   1          563  0.599574
# 9    深圳前进天虹       7  2,015   2          0  秋季  浅口   2          354  0.385201
# 10   深圳前进天虹       7  2,015   2          0  秋季  深口   3  392.3333333  0.346482
# 11   深圳前进天虹       7  2,015   3          0  冬季  中靴   1          499  0.312070
# 12   深圳前进天虹       7  2,015   3          0  冬季  低靴   8          557  0.394616
# 13   深圳前进天虹       7  2,015   3          0  冬季  高靴   2          800  0.400200
# 14   深圳前进天虹       7  2,015   3          0  春季  浅口   3          507  0.534247
# 15   深圳前进天虹       7  2,015   3          0  秋季  浅口   1          239  0.265851
# 16   深圳前进天虹       7  2,015   3          0  秋季  深口   1          399  0.399399
# 17   深圳前进天虹       7  2,015   4          0  冬季  低靴  19  566.5263158  0.398947
# 18   深圳前进天虹       7  2,015   4          0  冬季  高靴   1          899  0.449725
# 19   深圳前进天虹       7  2,015   4          0  春季  浅口   4        473.5  0.500264
# 20   深圳前进天虹       7  2,015   4          0  秋季  浅口   2          360  0.400445
# 21   深圳前进天虹       7  2,015   4          0  秋季  深口   3          423  0.438039
# 22   深圳前进天虹       7  2,015   5          0  冬季  低靴  16     568.1875  0.404332
# 23   深圳前进天虹       7  2,015   5          0  冬季  高靴   1          899  0.449725
# 24   深圳前进天虹       7  2,015   5          0  春季  浅口   3          468  0.500178
# 25   深圳前进天虹       7  2,015   5          0  秋季  浅口   2          334  0.371524
# 26   深圳前进天虹       7  2,015   5          0  秋季  深口   4       374.75  0.375125
# 27   深圳前进天虹       7  2,015   6          0  冬季  中靴   1          639  0.376104
# 28   深圳前进天虹       7  2,015   6          0  冬季  低靴  30  574.9028567  0.394941
# 29   深圳前进天虹       7  2,015   6          0  春季  浅口   1        375.6  0.400000
# ..      ...     ...    ...  ..        ...  ..  ..  ..          ...       ...
# 649  深圳前进天虹       7  2,016  50          0  冬季  中靴   8  487.1666625  0.333333
# 650  深圳前进天虹       7  2,016  50          0  冬季  低靴  90  494.8666711  0.330621
# 651  深圳前进天虹       7  2,016  50          0  冬季  裸靴  14  442.5238143  0.333333
# 652  深圳前进天虹       7  2,016  50          0  冬季  长靴   5        719.4  0.315665
# 653  深圳前进天虹       7  2,016  50          0  冬季  高靴   8   591.166675  0.288515
# 654  深圳前进天虹       7  2,016  50          0  春季  中空   1          376  0.400426
# 655  深圳前进天虹       7  2,016  50          0  春季  后空   1          305  0.305305
# 656  深圳前进天虹       7  2,016  50          0  春季  浅口  32     366.9375  0.393921
# 657  深圳前进天虹       7  2,016  50          0  春季  深口   4       409.25  0.425637
# 658  深圳前进天虹       7  2,016  50          0  秋季  浅口  15        362.8  0.375440
# 659  深圳前进天虹       7  2,016  50          0  秋季  深口  22  419.6212136  0.372575
# 660  深圳前进天虹       7  2,016  51          0  冬季  中靴   3  555.6666667  0.362628
# 661  深圳前进天虹       7  2,016  51          0  冬季  低靴  12   559.472225  0.390602
# 662  深圳前进天虹       7  2,016  51          0  春季  浅口  11  417.1818182  0.444714
# 663  深圳前进天虹       7  2,016  51          0  春季  深口   1          376  0.400426
# 664  深圳前进天虹       7  2,016  51          0  秋季  浅口   3  375.6666667  0.387685
# 665  深圳前进天虹       7  2,016  51          0  秋季  深口   5          397  0.342537
# 666  深圳前进天虹       7  2,016  52          0  冬季  中靴   4   524.666675  0.333333
# 667  深圳前进天虹       7  2,016  52          0  冬季  低靴  45  523.8000022  0.355762
# 668  深圳前进天虹       7  2,016  52          0  冬季  裸靴   8  441.3333375  0.333333
# 669  深圳前进天虹       7  2,016  52          0  冬季  高靴   1          799  0.420748
# 670  深圳前进天虹       7  2,016  52          0  春季  浅口  10        396.1  0.412175
# 671  深圳前进天虹       7  2,016  52          0  秋季  浅口   8       379.38  0.396111
# 672  深圳前进天虹       7  2,016  52          0  秋季  深口   8       423.04  0.356546
# 673  深圳前进天虹       7  2,016  53          0  冬季  中靴   3          548  0.365355
# 674  深圳前进天虹       7  2,016  53          0  冬季  低靴  12        556.5  0.371248
# 675  深圳前进天虹       7  2,016  53          0  冬季  高靴   1          799  0.363347
# 676  深圳前进天虹       7  2,016  53          0  春季  浅口   8      393.125  0.418107
# 677  深圳前进天虹       7  2,016  53          0  秋季  浅口   1          388  0.400413
# 678  深圳前进天虹       7  2,016  53          0  秋季  深口   5        458.8  0.402809
#
# [679 rows x 10 columns]

# %%
fig, ax = plt.subplots()
ax.scatter(x = a1['均价'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('均价'，fontsize=13)
plt.show()
# Out:
#   File "<ipython-input-16-b1be49ae136c>", line 4
#     plt.xlabel('均价'，fontsize=13)
#                            ^
# SyntaxError: invalid character in identifier

# %%
fig, ax = plt.subplots()
ax.scatter(x = a1['均价'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('均价',fontsize=13)
plt.show()

# %%
ai.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6d4de2367256> in <module>
# ----> 1 ai.head()
#
# NameError: name 'ai' is not defined

# %%
a1.head()
# Out:
#      店铺名称  地理位置指数     年份  周次  是否包含法定节假日  季节  大类  销量      均价        促销
# 0  深圳前进天虹       7  2,015   1          1  冬季  中靴   2     599  0.374818
# 1  深圳前进天虹       7  2,015   1          1  冬季  低靴  29  506.66  0.367592
# 2  深圳前进天虹       7  2,015   1          1  冬季  长靴   2  683.83  0.325790
# 3  深圳前进天虹       7  2,015   1          1  冬季  高靴   2     800  0.400000
# 4  深圳前进天虹       7  2,015   1          1  春季  浅口   1   375.6  0.400000

# %%
a1.describe()
# Out:
#        地理位置指数          周次   是否包含法定节假日          销量          促销
# count   679.0  679.000000  679.000000  679.000000  679.000000
# mean      7.0   27.462445    0.188513    6.944035    0.375835
# std       0.0   15.229551    0.391409   10.455967    0.081540
# min       7.0    1.000000    0.000000    1.000000    0.131332
# 25%       7.0   14.000000    0.000000    2.000000    0.318424
# 50%       7.0   28.000000    0.000000    4.000000    0.378146
# 75%       7.0   40.500000    0.000000    8.000000    0.435191
# max       7.0   53.000000    1.000000   91.000000    0.679680

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['促销'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('促销',fontsize=13)
plt.show()

# %%
a1.head()
# Out:
#      店铺名称  地理位置指数     年份  周次  是否包含法定节假日  季节  大类  销量      均价        促销
# 0  深圳前进天虹       7  2,015   1          1  冬季  中靴   2     599  0.374818
# 1  深圳前进天虹       7  2,015   1          1  冬季  低靴  29  506.66  0.367592
# 2  深圳前进天虹       7  2,015   1          1  冬季  长靴   2  683.83  0.325790
# 3  深圳前进天虹       7  2,015   1          1  冬季  高靴   2     800  0.400000
# 4  深圳前进天虹       7  2,015   1          1  春季  浅口   1   375.6  0.400000

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['季节'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('季节',fontsize=13)
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['季节'], y = a1['大类'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['大类'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['大类'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['大类'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['大类'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['大类'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f7c75d32593e> in <module>
# ----> 1 fig, ax1 = plt.subplots()
#       2 ax1.scatter(x = a1['大类'], y = a1['销量'])
#       3 plt.ylabel('销量',fontsize=13)
#       4 plt.xlabel('大类',fontsize=13)
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
from scipy import stats
from scipy.stats import norm,skew
all_data = pd.read_csv('sale所在周次节假日.csv')
all_data.head()
# Out:
# /home/lin/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:1003: UserWarning: Duplicate key in file "/home/lin/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc", line #197
#   (fname, cnt))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5ae1601921da> in <module>
#       6 from scipy import stats
#       7 from scipy.stats import norm,skew
# ----> 8 all_data = pd.read_csv('sale所在周次节假日.csv')
#       9 all_data.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'sale\xe6\x89\x80\xe5\x9c\xa8\xe5\x91\xa8\xe6\xac\xa1\xe8\x8a\x82\xe5\x81\x87\xe6\x97\xa5.csv' does not exist

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
from scipy import stats
from scipy.stats import norm,skew
all_data = pd.read_csv('sales所在周次节假日.csv')
all_data.head()
# Out:
#      店铺名称  地理位置指数     年份  周次  是否包含法定节假日  季节  大类  销量      均价        促销
# 0  深圳前进天虹       7  2,015   1          1  冬季  中靴   2     599  0.374818
# 1  深圳前进天虹       7  2,015   1          1  冬季  低靴  29  506.66  0.367592
# 2  深圳前进天虹       7  2,015   1          1  冬季  长靴   2  683.83  0.325790
# 3  深圳前进天虹       7  2,015   1          1  冬季  高靴   2     800  0.400000
# 4  深圳前进天虹       7  2,015   1          1  春季  浅口   1   375.6  0.400000

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['大类'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f7c75d32593e> in <module>
#       1 fig, ax1 = plt.subplots()
# ----> 2 ax1.scatter(x = a1['大类'], y = a1['销量'])
#       3 plt.ylabel('销量',fontsize=13)
#       4 plt.xlabel('大类',fontsize=13)
#       5 plt.show()
#
# NameError: name 'a1' is not defined

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = a1['大类'], y = a1['销量'])
plt.ylabel('销量',fontsize=13)
plt.xlabel('大类',fontsize=13)
plt.show()
